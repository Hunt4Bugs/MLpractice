# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Activation
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd

# %%
#get data
print "Loading Data"
dat = pd.read_csv('train.csv', sep=',', header=0).values
finaldat = pd.read_csv('test.csv', sep=',', header=0).values
finalx = np.array([i[::] for i in finaldat])
trainx = np.array([i[1::] for i in dat])
trainy = np.array([i[0] for i in dat])
ty = []
for i in range(len(trainy)):
	test = [0.0] * 10
	test[int(trainy[i])] = 1.0
	ty.append(test)
trainy = np.array(ty)

testx = trainx[int(len(trainx) * .7)::]
testy = trainy[int(len(trainy) * .7)::]
# Out:
# Loading Data

# %%
#declare and train model
print "Training Network"
model = Sequential([
	Dense(24, input_dim=784),
	Activation('sigmoid'),
	Dense(10),
	Activation('sigmoid')
])

model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True), metrics=['accuracy'])
model.fit(trainx, trainy, batch_size=128, nb_epoch=1, validation_data=(testx,testy))
evals = model.evaluate(testx, testy, verbose=1)
print ""
print evals
results = model.predict_classes(finalx)
results = pd.DataFrame({'ImageId':[i+1 for i in range(len(results))],'Label':results.tolist()})
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/lock_dir/lock
# Training Network
#
# ['/usr/local/cuda-8.0/bin/nvcc', '-shared', '-O3', '--maxrregcount=32', '-arch=sm_52', '-m64', '-Xcompiler', '-fno-math-errno,-Wno-unused-label,-Wno-unused-variable,-Wno-write-strings,-DCUDA_NDARRAY_CUH=c72d035fdf91890f3b36710688069b2e,-DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION,-fPIC,-fvisibility=hidden', '-Xlinker', '-rpath,/home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/cuda_ndarray', '-I/home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/cuda_ndarray', '-I/usr/local/cuda-8.0/include', '-I/usr/local/lib/python2.7/dist-packages/numpy/core/include', '-I/usr/include/python2.7', '-I/usr/local/lib/python2.7/dist-packages/theano/gof', '-I/usr/local/lib/python2.7/dist-packages/theano/sandbox/cuda', '-o', '/home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/tmpukQQjr/19eaed16bbe8051baf484ccf1bd89231.so', 'mod.cu', '-L/home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/cuda_ndarray', '-L/usr/lib', '-lcudart', '-lcublas', '-lcuda_ndarray', '-lpython2.7']
# 1 #include <Python.h>
# 2 #include <iostream>
# 3 #include "theano_mod_helper.h"
# 4 #include "cuda_ndarray.cuh"
# 5 //////////////////////
# 6 ////  Support Code
# 7 //////////////////////
# 8
# 9
# 10 #define INTDIV_POW2(a, b) (a >> b)
# 11 #define INTMOD_POW2(a, b) (a & ((1<<b)-1))
# 12         // GpuElemwise{Add}[(0, 0)]
# 13 // node.op.destroy_map={0: [0]}
# 14 //    Input   0 CudaNdarrayType(float32, matrix)
# 15 //    Input   1 CudaNdarrayType(float32, row)
# 16 //    Output  0 CudaNdarrayType(float32, matrix)
# 17 static __global__ void kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_1(unsigned int numEls
# 18 	, const int dim0
# 19 	, const float * i0_data, int i0_str_0
# 20 	, const float * i1_data, int i1_str_0
# 21 	, float * o0_data, int o0_str_0
# 22 	)
# 23 {
# 24     const int idx = blockIdx.x * blockDim.x + threadIdx.x;
# 25     const int numThreads = blockDim.x * gridDim.x;
# 26     for (int i = idx; i < numEls; i += numThreads) {
# 27         int ii = i;
# 28         const float * ii_i0_data = i0_data;
# 29         const float * ii_i1_data = i1_data;
# 30         float * ii_o0_data = o0_data;
# 31         int pos0 = ii;
# 32         ii_i0_data += pos0 * i0_str_0;
# 33         ii_i1_data += pos0 * i1_str_0;
# 34         ii_o0_data += pos0 * o0_str_0;
# 35 npy_float32 o0_i;
# 36         o0_i = ii_i0_data[0] + ii_i1_data[0];
# 37 ii_o0_data[0] = o0_i;
# 38     }
# 39 }
# 40 // GpuElemwise{Add}[(0, 0)]
# 41 // node.op.destroy_map={0: [0]}
# 42 //    Input   0 CudaNdarrayType(float32, matrix)
# 43 //    Input   1 CudaNdarrayType(float32, row)
# 44 //    Output  0 CudaNdarrayType(float32, matrix)
# 45 static __global__ void kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_2(unsigned int numEls
# 46 	, const int dim0, const int dim1
# 47 	, const float * i0_data, int i0_str_0, int i0_str_1
# 48 	, const float * i1_data, int i1_str_0, int i1_str_1
# 49 	, float * o0_data, int o0_str_0, int o0_str_1
# 50 	)
# 51 {
# 52     const int idx = blockIdx.x * blockDim.x + threadIdx.x;
# 53     const int numThreads = blockDim.x * gridDim.x;
# 54     for (int i = idx; i < numEls; i += numThreads) {
# 55         int ii = i;
# 56         const float * ii_i0_data = i0_data;
# 57         const float * ii_i1_data = i1_data;
# 58         float * ii_o0_data = o0_data;
# 59         int pos1 = ii % dim1;
# 60         ii = ii / dim1;
# 61         ii_i0_data += pos1 * i0_str_1;
# 62         ii_i1_data += pos1 * i1_str_1;
# 63         ii_o0_data += pos1 * o0_str_1;
# 64         int pos0 = ii;
# 65         ii_i0_data += pos0 * i0_str_0;
# 66         ii_i1_data += pos0 * i1_str_0;
# 67         ii_o0_data += pos0 * o0_str_0;
# 68 npy_float32 o0_i;
# 69         o0_i = ii_i0_data[0] + ii_i1_data[0];
# 70 ii_o0_data[0] = o0_i;
# 71     }
# 72 }
# 73 // GpuElemwise{Add}[(0, 0)]
# 74 // node.op.destroy_map={0: [0]}
# 75 //    Input   0 CudaNdarrayType(float32, matrix)
# 76 //    Input   1 CudaNdarrayType(float32, row)
# 77 //    Output  0 CudaNdarrayType(float32, matrix)
# 78 static __global__ void kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_Ccontiguous (unsigned int numEls
# 79 	, const float * i0_data
# 80 	, const float * i1_data
# 81 	, float * o0_data
# 82 	)
# 83 {
# 84     const int idx = blockIdx.x * blockDim.x + threadIdx.x;
# 85     const int numThreads = blockDim.x * gridDim.x;
# 86     for (int i = idx; i < numEls; i += numThreads) {
# 87 npy_float32 o0_i;
# 88         o0_i = i0_data[i] + i1_data[i];
# 89 o0_data[i] = o0_i;
# 90     }
# 91 }
# 92
# 93         static void can_collapse_node_19eaed16bbe8051baf484ccf1bd89231_0(int nd, const int * dims, const int * strides, int collapse[])
# 94         {
# 95             //can we collapse dims[i] and dims[i-1]
# 96             for(int i=nd-1;i>0;i--){
# 97                 if(strides[i]*dims[i]==strides[i-1]){//the dims nd-1 are not strided again dimension nd
# 98                     collapse[i]=1;
# 99                 }else collapse[i]=0;
# 100             }
# 101         }
# 102
# 103
# 104         static int callkernel_node_19eaed16bbe8051baf484ccf1bd89231_0(unsigned int numEls, const int d,
# 105             const int * dims,
# 106             const float * i0_data, const int * i0_str, const float * i1_data, const int * i1_str,
# 107             float * o0_data, const int * o0_str)
# 108         {
# 109             numEls = dims[0]*dims[1]*1;
# 110
# 111 int local_dims[2];
# 112
# 113             int local_str[2][2];
# 114             int local_ostr[1][2];
# 115
# 116
# 117         int nd_collapse = 2;
# 118         for(int i=0;i<2;i++){//init new dim
# 119           local_dims[i]=dims[i];
# 120         }
# 121
# 122
# 123             for(int i=0;i<2;i++){//init new strides
# 124               local_str[0][i]=i0_str[i];
# 125             }
# 126
# 127
# 128             for(int i=0;i<2;i++){//init new strides
# 129               local_str[1][i]=i1_str[i];
# 130             }
# 131
# 132
# 133             for(int i=0;i<2;i++){//init new strides
# 134               local_ostr[0][i]=o0_str[i];
# 135             }
# 136
# 137
# 138         for(int id=0;id<nd_collapse;id++){
# 139
# 140           bool all_broadcast=true;
# 141           for(int input_id=0;input_id<2;input_id++){
# 142             if(local_str[input_id][id]!=0 || local_dims[id]!=1) all_broadcast= false;
# 143           }
# 144           for(int input_id=0;input_id<1;input_id++){
# 145             if(local_ostr[input_id][id]!=0 || local_dims[id]!=1) all_broadcast= false;
# 146           }
# 147           if(all_broadcast){
# 148             for(int j=id+1;j<nd_collapse;j++)//remove dims i from the array
# 149               local_dims[j-1]=local_dims[j];
# 150             for(int input_id=0;input_id<2;input_id++){
# 151               for(int j=id+1;j<nd_collapse;j++){//remove dims i from the array
# 152                 local_str[input_id][j-1]=local_str[input_id][j];
# 153               }
# 154             }
# 155             for(int output_id=0;output_id<1;output_id++){
# 156               for(int j=id+1;j<nd_collapse;j++){//remove dims i from the array
# 157                 local_ostr[output_id][j-1]=local_ostr[output_id][j];
# 158               }
# 159             }
# 160             nd_collapse--; id--;
# 161           }
# 162         }
# 163
# 164 int nd_collapse_[2] = {1,1};
# 165
# 166                         int nd_collapse_0[2] = {1,1};
# 167
# 168 can_collapse_node_19eaed16bbe8051baf484ccf1bd89231_0(nd_collapse, local_dims, local_str[0], nd_collapse_0);
# 169 for(int i=0;i<nd_collapse;i++){
# 170 if(nd_collapse_0[i]==0)
# 171 nd_collapse_[i]=0;
# 172 }
# 173
# 174
# 175                         int nd_collapse_1[2] = {1,1};
# 176
# 177 can_collapse_node_19eaed16bbe8051baf484ccf1bd89231_0(nd_collapse, local_dims, local_str[1], nd_collapse_1);
# 178 for(int i=0;i<nd_collapse;i++){
# 179 if(nd_collapse_1[i]==0)
# 180 nd_collapse_[i]=0;
# 181 }
# 182
# 183
# 184             for(int i=nd_collapse-1;i>0;i--){
# 185               if(nd_collapse_[i]==1){
# 186                 local_str[0][i-1]=local_str[0][i];//set new strides
# 187                 for(int j=i+1;j<nd_collapse;j++)//remove stride i from the array
# 188                   local_str[0][j-1]=local_str[0][j];
# 189                 }
# 190             }
# 191
# 192
# 193             for(int i=nd_collapse-1;i>0;i--){
# 194               if(nd_collapse_[i]==1){
# 195                 local_str[1][i-1]=local_str[1][i];//set new strides
# 196                 for(int j=i+1;j<nd_collapse;j++)//remove stride i from the array
# 197                   local_str[1][j-1]=local_str[1][j];
# 198                 }
# 199             }
# 200
# 201
# 202             for(int i=nd_collapse-1;i>0;i--){
# 203               if(nd_collapse_[i]==1){
# 204                 local_ostr[0][i-1]=local_ostr[0][i];//set new strides
# 205                 for(int j=i+1;j<nd_collapse;j++)//remove stride i from the array
# 206                   local_ostr[0][j-1]=local_ostr[0][j];
# 207                 }
# 208             }
# 209
# 210
# 211         for(int i=nd_collapse-1;i>0;i--){
# 212           if(nd_collapse_[i]==1){
# 213             local_dims[i-1]*=local_dims[i];//set new dims
# 214             for(int j=i+1;j<nd_collapse;j++)//remove dims i from the array
# 215               local_dims[j-1]=local_dims[j];
# 216           }
# 217         }
# 218
# 219
# 220         for(int i=1, end=nd_collapse;i<end;i++){
# 221           if(nd_collapse_[i]==1)nd_collapse--;
# 222         }
# 223         if(nd_collapse == 1
# 224  &&  local_str[0][nd_collapse-1]==1  && local_str[1][nd_collapse-1]==1  && local_ostr[0][nd_collapse-1]==1
# 225 ){nd_collapse=0;}
# 226 if(numEls==0) return 0;
# 227 switch (nd_collapse==0?0:min(2,nd_collapse)) {
# 228 case 0: {
# 229
# 230                 //first use at least a full warp
# 231                 int threads_per_block = std::min(numEls,  (unsigned int)32); //WARP SIZE
# 232
# 233                 //next start adding multiprocessors
# 234                 int n_blocks = std::min(numEls/threads_per_block + (numEls % threads_per_block?1:0), (unsigned int)30); // UP TO NUMBER OF MULTIPROCESSORS
# 235
# 236                 // next start adding more warps per multiprocessor
# 237                 if (threads_per_block * n_blocks < numEls)
# 238                     threads_per_block = std::min(numEls/n_blocks, (unsigned int)NUM_VECTOR_OP_THREADS_PER_BLOCK);
# 239                 kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_Ccontiguous<<<n_blocks, threads_per_block>>>(numEls, i0_data, i1_data, o0_data);
# 240
# 241                 //std::cerr << "calling callkernel returned\n";
# 242
# 243
# 244                 CNDA_THREAD_SYNC;
# 245                 cudaError_t err = cudaGetLastError();
# 246                 if( cudaSuccess != err)
# 247                 {
# 248                     PyErr_Format(PyExc_RuntimeError, "Cuda error: %s: %s.\n    n_blocks=%i threads_per_block=%i\n   Call: %s\n",
# 249                          "GpuElemwise node_19eaed16bbe8051baf484ccf1bd89231_0 Add", cudaGetErrorString(err),
# 250                          n_blocks, threads_per_block,
# 251                          "kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_Ccontiguous<<<n_blocks, threads_per_block>>>(numEls, i0_data, i1_data, o0_data)");
# 252                     return -1;
# 253
# 254                 }
# 255
# 256                 return 0;
# 257
# 258         } break;
# 259 case 1: {
# 260
# 261                 //first use at least a full warp
# 262                 int threads_per_block = std::min(numEls, (unsigned int)32); //WARP SIZE
# 263
# 264                 //next start adding multiprocessors
# 265                 int n_blocks = std::min(numEls/threads_per_block + (numEls % threads_per_block?1:0), (unsigned int)30); // UP TO NUMBER OF MULTIPROCESSORS
# 266
# 267                 // next start adding more warps per multiprocessor
# 268                 if (threads_per_block * n_blocks < numEls)
# 269                     threads_per_block = std::min(numEls/n_blocks, (unsigned int)NUM_VECTOR_OP_THREADS_PER_BLOCK);
# 270
# 271                 kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_1<<<n_blocks, threads_per_block>>>(numEls, local_dims[0], i0_data, local_str[0][0], i1_data, local_str[1][0], o0_data, local_ostr[0][0]);
# 272
# 273
# 274                 CNDA_THREAD_SYNC;
# 275                 cudaError_t err = cudaGetLastError();
# 276                 if( cudaSuccess != err)
# 277                 {
# 278                     PyErr_Format(PyExc_RuntimeError, "Cuda error: %s: %s.\n    n_blocks=%i threads_per_block=%i\n   Call: %s\n",
# 279                          "GpuElemwise node_19eaed16bbe8051baf484ccf1bd89231_0 Add", cudaGetErrorString(err),
# 280                          n_blocks, threads_per_block,
# 281                          "kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_Ccontiguous<<<n_blocks, threads_per_block>>>(numEls, local_dims[0], i0_data, local_str[0][0], i1_data, local_str[1][0], o0_data, local_ostr[0][0])");
# 282                     return -1;
# 283
# 284                 }
# 285                 return 0;
# 286
# 287         } break;
# 288 case 2: {
# 289
# 290                 //first use at least a full warp
# 291                 int threads_per_block = std::min(numEls, (unsigned int)32); //WARP SIZE
# 292
# 293                 //next start adding multiprocessors
# 294                 int n_blocks = std::min(numEls/threads_per_block + (numEls % threads_per_block?1:0), (unsigned int)30); // UP TO NUMBER OF MULTIPROCESSORS
# 295
# 296                 // next start adding more warps per multiprocessor
# 297                 if (threads_per_block * n_blocks < numEls)
# 298                     threads_per_block = std::min(numEls/n_blocks, (unsigned int)NUM_VECTOR_OP_THREADS_PER_BLOCK);
# 299
# 300                 kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_2<<<n_blocks, threads_per_block>>>(numEls, local_dims[0], local_dims[1], i0_data, local_str[0][0], local_str[0][1], i1_data, local_str[1][0], local_str[1][1], o0_data, local_ostr[0][0], local_ostr[0][1]);
# 301
# 302
# 303                 CNDA_THREAD_SYNC;
# 304                 cudaError_t err = cudaGetLastError();
# 305                 if( cudaSuccess != err)
# 306                 {
# 307                     PyErr_Format(PyExc_RuntimeError, "Cuda error: %s: %s.\n    n_blocks=%i threads_per_block=%i\n   Call: %s\n",
# 308                          "GpuElemwise node_19eaed16bbe8051baf484ccf1bd89231_0 Add", cudaGetErrorString(err),
# 309                          n_blocks, threads_per_block,
# 310                          "kernel_Add_node_19eaed16bbe8051baf484ccf1bd89231_0_Ccontiguous<<<n_blocks, threads_per_block>>>(numEls, local_dims[0], local_dims[1], i0_data, local_str[0][0], local_str[0][1], i1_data, local_str[1][0], local_str[1][1], o0_data, local_ostr[0][0], local_ostr[0][1])");
# 311                     return -1;
# 312
# 313                 }
# 314                 return 0;
# 315
# 316         } break;
# 317 }
# 318 return -2;
# 319 }
# 320
# 321
# 322     namespace {
# 323     struct __struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231 {
# 324         PyObject* __ERROR;
# 325
# 326         PyObject* storage_V3;
# 327 PyObject* storage_V5;
# 328 PyObject* storage_V1;
# 329
# 330
# 331         __struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231() {
# 332             // This is only somewhat safe because we:
# 333             //  1) Are not a virtual class
# 334             //  2) Do not use any virtual classes in the members
# 335             //  3) Deal with mostly POD and pointers
# 336
# 337             // If this changes, we would have to revise this, but for
# 338             // now I am tired of chasing segfaults because
# 339             // initialization code had an error and some pointer has
# 340             // a junk value.
# 341             memset(this, 0, sizeof(*this));
# 342         }
# 343         ~__struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231(void) {
# 344             cleanup();
# 345         }
# 346
# 347         int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V5, PyObject* storage_V1) {
# 348             Py_XINCREF(storage_V3);
# 349 Py_XINCREF(storage_V5);
# 350 Py_XINCREF(storage_V1);
# 351             this->storage_V3 = storage_V3;
# 352 this->storage_V5 = storage_V5;
# 353 this->storage_V1 = storage_V1;
# 354
# 355
# 356
# 357
# 358
# 359             this->__ERROR = __ERROR;
# 360             return 0;
# 361         }
# 362         void cleanup(void) {
# 363             __label_1:
# 364
# 365 double __DUMMY_1;
# 366 __label_3:
# 367
# 368 double __DUMMY_3;
# 369 __label_5:
# 370
# 371 double __DUMMY_5;
# 372 __label_8:
# 373
# 374 double __DUMMY_8;
# 375
# 376             Py_XDECREF(this->storage_V3);
# 377 Py_XDECREF(this->storage_V5);
# 378 Py_XDECREF(this->storage_V1);
# 379         }
# 380         int run(void) {
# 381             int __failure = 0;
# 382
# 383     PyObject* py_V1;
# 384      CudaNdarray * V1;
# 385     PyObject* py_V3;
# 386      CudaNdarray * V3;
# 387     PyObject* py_V5;
# 388      CudaNdarray * V5;
# 389 {
# 390
# 391     py_V1 = PyList_GET_ITEM(storage_V1, 0);
# 392     {Py_XINCREF(py_V1);}
# 393
# 394         if (py_V1 == Py_None)
# 395         {
# 396             V1 = NULL;
# 397         }
# 398         else
# 399         {
# 400
# 401         assert(py_V1->ob_refcnt >= 2); // There should be at least one ref from the container object,
# 402         // and one ref from the local scope.
# 403
# 404         if (CudaNdarray_Check(py_V1))
# 405         {
# 406             //fprintf(stderr, "c_extract CNDA object w refcnt %p %i\n", py_V1, (py_V1->ob_refcnt));
# 407             V1 = (CudaNdarray*)py_V1;
# 408             //std::cerr << "c_extract " << V1 << '\n';
# 409
# 410
# 411                 if (V1->nd != 2)
# 412                 {
# 413                     PyErr_Format(PyExc_RuntimeError,
# 414                                  "c_extract: Some CudaNdarray has rank %i, it was supposed to have rank 2",
# 415                                  V1->nd);
# 416                     V1 = NULL;
# 417                     {
# 418         __failure = 2;
# 419         if (!PyErr_Occurred()) {
# 420             PyErr_SetString(PyExc_RuntimeError,
# 421                 "Unexpected error in an Op's C code. "
# 422                 "No Python exception was set.");
# 423             }
# 424         goto __label_2;};
# 425                 }
# 426                 //std::cerr << "c_extract " << V1 << " nd check passed\n";
# 427
# 428
# 429                 assert(V1);
# 430                 Py_INCREF(py_V1);
# 431             }
# 432             else if (py_V1 == Py_None)
# 433             {
# 434                 PyErr_SetString(PyExc_TypeError,
# 435                                 "expected a CudaNdarray, not None");
# 436                 V1 = NULL;
# 437                 {
# 438         __failure = 2;
# 439         if (!PyErr_Occurred()) {
# 440             PyErr_SetString(PyExc_RuntimeError,
# 441                 "Unexpected error in an Op's C code. "
# 442                 "No Python exception was set.");
# 443             }
# 444         goto __label_2;};
# 445             }
# 446             else
# 447             {
# 448                 //fprintf(stderr, "FAILING c_extract CNDA object w refcnt %p %i\n", py_V1, (py_V1->ob_refcnt));
# 449                 PyErr_SetString(PyExc_TypeError, "Argument not a CudaNdarray");
# 450                 V1 = NULL;
# 451                 {
# 452         __failure = 2;
# 453         if (!PyErr_Occurred()) {
# 454             PyErr_SetString(PyExc_RuntimeError,
# 455                 "Unexpected error in an Op's C code. "
# 456                 "No Python exception was set.");
# 457             }
# 458         goto __label_2;};
# 459             }
# 460             //std::cerr << "c_extract done " << V1 << '\n';
# 461
# 462
# 463         }
# 464
# 465 {
# 466
# 467     py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 468     {Py_XINCREF(py_V3);}
# 469
# 470         assert(py_V3->ob_refcnt >= 2); // There should be at least one ref from the container object,
# 471         // and one ref from the local scope.
# 472
# 473         if (CudaNdarray_Check(py_V3))
# 474         {
# 475             //fprintf(stderr, "c_extract CNDA object w refcnt %p %i\n", py_V3, (py_V3->ob_refcnt));
# 476             V3 = (CudaNdarray*)py_V3;
# 477             //std::cerr << "c_extract " << V3 << '\n';
# 478
# 479
# 480                 if (V3->nd != 2)
# 481                 {
# 482                     PyErr_Format(PyExc_RuntimeError,
# 483                                  "c_extract: Some CudaNdarray has rank %i, it was supposed to have rank 2",
# 484                                  V3->nd);
# 485                     V3 = NULL;
# 486                     {
# 487         __failure = 4;
# 488         if (!PyErr_Occurred()) {
# 489             PyErr_SetString(PyExc_RuntimeError,
# 490                 "Unexpected error in an Op's C code. "
# 491                 "No Python exception was set.");
# 492             }
# 493         goto __label_4;};
# 494                 }
# 495                 //std::cerr << "c_extract " << V3 << " nd check passed\n";
# 496
# 497
# 498                 assert(V3);
# 499                 Py_INCREF(py_V3);
# 500             }
# 501             else if (py_V3 == Py_None)
# 502             {
# 503                 PyErr_SetString(PyExc_TypeError,
# 504                                 "expected a CudaNdarray, not None");
# 505                 V3 = NULL;
# 506                 {
# 507         __failure = 4;
# 508         if (!PyErr_Occurred()) {
# 509             PyErr_SetString(PyExc_RuntimeError,
# 510                 "Unexpected error in an Op's C code. "
# 511                 "No Python exception was set.");
# 512             }
# 513         goto __label_4;};
# 514             }
# 515             else
# 516             {
# 517                 //fprintf(stderr, "FAILING c_extract CNDA object w refcnt %p %i\n", py_V3, (py_V3->ob_refcnt));
# 518                 PyErr_SetString(PyExc_TypeError, "Argument not a CudaNdarray");
# 519                 V3 = NULL;
# 520                 {
# 521         __failure = 4;
# 522         if (!PyErr_Occurred()) {
# 523             PyErr_SetString(PyExc_RuntimeError,
# 524                 "Unexpected error in an Op's C code. "
# 525                 "No Python exception was set.");
# 526             }
# 527         goto __label_4;};
# 528             }
# 529             //std::cerr << "c_extract done " << V3 << '\n';
# 530
# 531
# 532 {
# 533
# 534     py_V5 = PyList_GET_ITEM(storage_V5, 0);
# 535     {Py_XINCREF(py_V5);}
# 536
# 537         assert(py_V5->ob_refcnt >= 2); // There should be at least one ref from the container object,
# 538         // and one ref from the local scope.
# 539
# 540         if (CudaNdarray_Check(py_V5))
# 541         {
# 542             //fprintf(stderr, "c_extract CNDA object w refcnt %p %i\n", py_V5, (py_V5->ob_refcnt));
# 543             V5 = (CudaNdarray*)py_V5;
# 544             //std::cerr << "c_extract " << V5 << '\n';
# 545
# 546
# 547                 if (V5->nd != 2)
# 548                 {
# 549                     PyErr_Format(PyExc_RuntimeError,
# 550                                  "c_extract: Some CudaNdarray has rank %i, it was supposed to have rank 2",
# 551                                  V5->nd);
# 552                     V5 = NULL;
# 553                     {
# 554         __failure = 6;
# 555         if (!PyErr_Occurred()) {
# 556             PyErr_SetString(PyExc_RuntimeError,
# 557                 "Unexpected error in an Op's C code. "
# 558                 "No Python exception was set.");
# 559             }
# 560         goto __label_6;};
# 561                 }
# 562                 //std::cerr << "c_extract " << V5 << " nd check passed\n";
# 563
# 564
# 565                 if (CudaNdarray_HOST_DIMS(V5)[0] != 1)
# 566                 {
# 567                     PyErr_Format(PyExc_RuntimeError,
# 568                                  "c_extract: Some CudaNdarray has dim %i on broadcastable dimension %i",
# 569                                  CudaNdarray_HOST_DIMS(V5)[0], 0);
# 570                     V5 = NULL;
# 571                     {
# 572         __failure = 6;
# 573         if (!PyErr_Occurred()) {
# 574             PyErr_SetString(PyExc_RuntimeError,
# 575                 "Unexpected error in an Op's C code. "
# 576                 "No Python exception was set.");
# 577             }
# 578         goto __label_6;};
# 579                 }
# 580                 //std::cerr << "c_extract " << V5 << "dim check 0 passed\n";
# 581                 //std::cerr << "c_extract " << V5 << "checking bcast 0 <" << V5->str<< ">\n";
# 582                 //std::cerr << "c_extract " << V5->str[0] << "\n";
# 583                 if (CudaNdarray_HOST_STRIDES(V5)[0])
# 584                 {
# 585                     //std::cerr << "c_extract bad stride detected...\n";
# 586                     PyErr_Format(PyExc_RuntimeError,
# 587                                  "c_extract: Some CudaNdarray has a nonzero stride %i on a broadcastable dimension %i",
# 588                                  CudaNdarray_HOST_STRIDES(V5)[0], 0);
# 589                     V5 = NULL;
# 590                     {
# 591         __failure = 6;
# 592         if (!PyErr_Occurred()) {
# 593             PyErr_SetString(PyExc_RuntimeError,
# 594                 "Unexpected error in an Op's C code. "
# 595                 "No Python exception was set.");
# 596             }
# 597         goto __label_6;};
# 598                 }
# 599                 //std::cerr << "c_extract " << V5 << "bcast check 0 passed\n";
# 600
# 601
# 602                 assert(V5);
# 603                 Py_INCREF(py_V5);
# 604             }
# 605             else if (py_V5 == Py_None)
# 606             {
# 607                 PyErr_SetString(PyExc_TypeError,
# 608                                 "expected a CudaNdarray, not None");
# 609                 V5 = NULL;
# 610                 {
# 611         __failure = 6;
# 612         if (!PyErr_Occurred()) {
# 613             PyErr_SetString(PyExc_RuntimeError,
# 614                 "Unexpected error in an Op's C code. "
# 615                 "No Python exception was set.");
# 616             }
# 617         goto __label_6;};
# 618             }
# 619             else
# 620             {
# 621                 //fprintf(stderr, "FAILING c_extract CNDA object w refcnt %p %i\n", py_V5, (py_V5->ob_refcnt));
# 622                 PyErr_SetString(PyExc_TypeError, "Argument not a CudaNdarray");
# 623                 V5 = NULL;
# 624                 {
# 625         __failure = 6;
# 626         if (!PyErr_Occurred()) {
# 627             PyErr_SetString(PyExc_RuntimeError,
# 628                 "Unexpected error in an Op's C code. "
# 629                 "No Python exception was set.");
# 630             }
# 631         goto __label_6;};
# 632             }
# 633             //std::cerr << "c_extract done " << V5 << '\n';
# 634
# 635
# 636 {
# 637 // Op class GpuElemwise
# 638
# 639         //std::cerr << "C_CODE Add START\n";
# 640         //standard elemwise size checks
# 641
# 642
# 643             int dims[2] = {1,1};
# 644
# 645
# 646                 int broadcasts_V3[2] = {0, 0};
# 647
# 648
# 649                 int broadcasts_V5[2] = {1, 0};
# 650
# 651
# 652         //std::cerr << "C_CODE Add checking input V3\n";
# 653         if (2 != V3->nd)
# 654         {
# 655             PyErr_Format(PyExc_TypeError,
# 656                          "need 2 dims, not %i", V3->nd);
# 657             {
# 658         __failure = 7;
# 659         if (!PyErr_Occurred()) {
# 660             PyErr_SetString(PyExc_RuntimeError,
# 661                 "Unexpected error in an Op's C code. "
# 662                 "No Python exception was set.");
# 663             }
# 664         goto __label_7;};
# 665         }
# 666         for (int i = 0; i< 2; ++i)
# 667         {
# 668             dims[i] = (dims[i] == 1) ? CudaNdarray_HOST_DIMS(V3)[i] : dims[i];
# 669             if ((!(broadcasts_V3[i] &&
# 670                  CudaNdarray_HOST_DIMS(V3)[i] == 1)) &&
# 671                 (dims[i] != CudaNdarray_HOST_DIMS(V3)[i]))
# 672             {
# 673                 //std::cerr << "C_CODE Add checking input V3 failed\n";
# 674                 PyErr_Format(PyExc_ValueError,
# 675                              "GpuElemwise. Input dimension mis-match. Input"
# 676                              " 0 (indices start at 0) has shape[%i] == %i"
# 677                              ", but the output's size on that axis is %i.",
# 678                              i,
# 679                              CudaNdarray_HOST_DIMS(V3)[i],
# 680                              dims[i]
# 681                             );
# 682                 {
# 683         __failure = 7;
# 684         if (!PyErr_Occurred()) {
# 685             PyErr_SetString(PyExc_RuntimeError,
# 686                 "Unexpected error in an Op's C code. "
# 687                 "No Python exception was set.");
# 688             }
# 689         goto __label_7;};
# 690             }
# 691         }
# 692
# 693
# 694         //std::cerr << "C_CODE Add checking input V5\n";
# 695         if (2 != V5->nd)
# 696         {
# 697             PyErr_Format(PyExc_TypeError,
# 698                          "need 2 dims, not %i", V5->nd);
# 699             {
# 700         __failure = 7;
# 701         if (!PyErr_Occurred()) {
# 702             PyErr_SetString(PyExc_RuntimeError,
# 703                 "Unexpected error in an Op's C code. "
# 704                 "No Python exception was set.");
# 705             }
# 706         goto __label_7;};
# 707         }
# 708         for (int i = 0; i< 2; ++i)
# 709         {
# 710             dims[i] = (dims[i] == 1) ? CudaNdarray_HOST_DIMS(V5)[i] : dims[i];
# 711             if ((!(broadcasts_V5[i] &&
# 712                  CudaNdarray_HOST_DIMS(V5)[i] == 1)) &&
# 713                 (dims[i] != CudaNdarray_HOST_DIMS(V5)[i]))
# 714             {
# 715                 //std::cerr << "C_CODE Add checking input V5 failed\n";
# 716                 PyErr_Format(PyExc_ValueError,
# 717                              "GpuElemwise. Input dimension mis-match. Input"
# 718                              " 1 (indices start at 0) has shape[%i] == %i"
# 719                              ", but the output's size on that axis is %i.",
# 720                              i,
# 721                              CudaNdarray_HOST_DIMS(V5)[i],
# 722                              dims[i]
# 723                             );
# 724                 {
# 725         __failure = 7;
# 726         if (!PyErr_Occurred()) {
# 727             PyErr_SetString(PyExc_RuntimeError,
# 728                 "Unexpected error in an Op's C code. "
# 729                 "No Python exception was set.");
# 730             }
# 731         goto __label_7;};
# 732             }
# 733         }
# 734
# 735
# 736         Py_XDECREF(V1);
# 737         V1 = V3;
# 738         Py_INCREF(V1);
# 739         for (int i = 0; (i< 2) && (V1); ++i) {
# 740             if (dims[i] != CudaNdarray_HOST_DIMS(V1)[i])
# 741             {
# 742                 PyErr_Format(PyExc_ValueError,
# 743                              "GpuElemwise. Output dimension mis-match. Output"
# 744                              " 0 (indices start at 0), working inplace"
# 745                              " on input 0, has shape[%i] == %i"
# 746                              ", but the output's size on that axis is %i.",
# 747                              i,
# 748                              CudaNdarray_HOST_DIMS(V1)[i],
# 749                              dims[i]
# 750                             );
# 751                 Py_DECREF(V1);
# 752                 V1 = NULL;
# 753                 {
# 754         __failure = 7;
# 755         if (!PyErr_Occurred()) {
# 756             PyErr_SetString(PyExc_RuntimeError,
# 757                 "Unexpected error in an Op's C code. "
# 758                 "No Python exception was set.");
# 759             }
# 760         goto __label_7;};
# 761             }
# 762         }
# 763         //std::cerr << "ELEMWISE NEW V1 nd" << V1->nd << "\n";
# 764         //std::cerr << "ELEMWISE NEW V1 data" << V1->devdata << "\n";
# 765
# 766
# 767         {
# 768             //new block so that failure gotos don't skip over variable initialization
# 769             //std::cerr << "calling callkernel\n";
# 770             if (callkernel_node_19eaed16bbe8051baf484ccf1bd89231_0(1, 0, dims
# 771
# 772
# 773                         , CudaNdarray_DEV_DATA(V3), CudaNdarray_HOST_STRIDES(V3)
# 774
# 775
# 776                         , CudaNdarray_DEV_DATA(V5), CudaNdarray_HOST_STRIDES(V5)
# 777
# 778
# 779                         , CudaNdarray_DEV_DATA(V1), CudaNdarray_HOST_STRIDES(V1)
# 780
# 781
# 782                         ))
# 783             {
# 784                  // error
# 785
# 786
# 787                 Py_DECREF(V1);
# 788                 V1 = NULL;
# 789
# 790
# 791                 {
# 792         __failure = 7;
# 793         if (!PyErr_Occurred()) {
# 794             PyErr_SetString(PyExc_RuntimeError,
# 795                 "Unexpected error in an Op's C code. "
# 796                 "No Python exception was set.");
# 797             }
# 798         goto __label_7;};
# 799             }
# 800             else // no error
# 801             {
# 802             }
# 803         }
# 804         //std::cerr << "C_CODE Add END\n";
# 805
# 806 __label_7:
# 807
# 808 double __DUMMY_7;
# 809
# 810 }
# 811 __label_6:
# 812
# 813         //std::cerr << "cleanup " << py_V5 << " " << V5 << "\n";
# 814         //fprintf(stderr, "c_cleanup CNDA py_object w refcnt %p %i\n", py_V5, (py_V5->ob_refcnt));
# 815         if (V5)
# 816         {
# 817             //fprintf(stderr, "c_cleanup CNDA cn_object w refcnt %p %i\n", V5, (V5->ob_refcnt));
# 818             Py_XDECREF(V5);
# 819         }
# 820         //std::cerr << "cleanup done" << py_V5 << "\n";
# 821
# 822     {Py_XDECREF(py_V5);}
# 823
# 824 double __DUMMY_6;
# 825
# 826 }
# 827 __label_4:
# 828
# 829         //std::cerr << "cleanup " << py_V3 << " " << V3 << "\n";
# 830         //fprintf(stderr, "c_cleanup CNDA py_object w refcnt %p %i\n", py_V3, (py_V3->ob_refcnt));
# 831         if (V3)
# 832         {
# 833             //fprintf(stderr, "c_cleanup CNDA cn_object w refcnt %p %i\n", V3, (V3->ob_refcnt));
# 834             Py_XDECREF(V3);
# 835         }
# 836         //std::cerr << "cleanup done" << py_V3 << "\n";
# 837
# 838     {Py_XDECREF(py_V3);}
# 839
# 840 double __DUMMY_4;
# 841
# 842 }
# 843 __label_2:
# 844
# 845     if (!__failure) {
# 846
# 847         //std::cerr << "sync\n";
# 848         if (NULL == V1) {
# 849             // failure: sync None to storage
# 850             Py_XDECREF(py_V1);
# 851             py_V1 = Py_None;
# 852             Py_INCREF(py_V1);
# 853         }
# 854         else
# 855         {
# 856             if (py_V1 != (PyObject*)V1)
# 857             {
# 858                 Py_XDECREF(py_V1);
# 859                 py_V1 = (PyObject*)V1;
# 860                 Py_INCREF(py_V1);
# 861             }
# 862             assert(py_V1->ob_refcnt);
# 863         }
# 864
# 865       PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 866       {Py_XINCREF(py_V1);}
# 867       PyList_SET_ITEM(storage_V1, 0, py_V1);
# 868       {Py_XDECREF(old);}
# 869     }
# 870
# 871         //std::cerr << "cleanup " << py_V1 << " " << V1 << "\n";
# 872         //fprintf(stderr, "c_cleanup CNDA py_object w refcnt %p %i\n", py_V1, (py_V1->ob_refcnt));
# 873         if (V1)
# 874         {
# 875             //fprintf(stderr, "c_cleanup CNDA cn_object w refcnt %p %i\n", V1, (V1->ob_refcnt));
# 876             Py_XDECREF(V1);
# 877         }
# 878         //std::cerr << "cleanup done" << py_V1 << "\n";
# 879
# 880     {Py_XDECREF(py_V1);}
# 881
# 882 double __DUMMY_2;
# 883
# 884 }
# 885
# 886
# 887         if (__failure) {
# 888             // When there is a failure, this code puts the exception
# 889             // in __ERROR.
# 890             PyObject* err_type = NULL;
# 891             PyObject* err_msg = NULL;
# 892             PyObject* err_traceback = NULL;
# 893             PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 894             if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 895             if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 896             if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 897             PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 898             PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 899             PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 900             PyList_SET_ITEM(__ERROR, 0, err_type);
# 901             PyList_SET_ITEM(__ERROR, 1, err_msg);
# 902             PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 903             {Py_XDECREF(old_err_type);}
# 904             {Py_XDECREF(old_err_msg);}
# 905             {Py_XDECREF(old_err_traceback);}
# 906         }
# 907         // The failure code is returned to index what code block failed.
# 908         return __failure;
# 909
# 910         }
# 911     };
# 912     }
# 913
# 914
# 915         static int __struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231_executor(__struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231* self) {
# 916             return self->run();
# 917         }
# 918
# 919         static void __struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231_destructor(void* executor, void* self) {
# 920             delete ((__struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231*)self);
# 921         }
# 922
# 923 //////////////////////
# 924 ////  Functions
# 925 //////////////////////
# 926 static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 927   assert(PyTuple_Check(argtuple));
# 928   if (4 != PyTuple_Size(argtuple)){
# 929      PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 4, got %i", (int)PyTuple_Size(argtuple));
# 930      return NULL;
# 931   }
# 932   __struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231* struct_ptr = new __struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231();
# 933   if (struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2),PyTuple_GET_ITEM(argtuple, 3) ) != 0) {
# 934     delete struct_ptr;
# 935     return NULL;
# 936   }
# 937   PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231_executor), struct_ptr, __struct_compiled_op_19eaed16bbe8051baf484ccf1bd89231_destructor);
# 938   return thunk; }
# 939
# 940 //////////////////////
# 941 ////  Module init
# 942 //////////////////////
# 943 static PyMethodDef MyMethods[] = {
# 944 	{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 945 	{NULL, NULL, 0, NULL}
# 946 };
# 947 PyMODINIT_FUNC init19eaed16bbe8051baf484ccf1bd89231(void){
# 948    (void) Py_InitModule("19eaed16bbe8051baf484ccf1bd89231", MyMethods);
# 949 }
# 950
# ===============================
# In file included from /usr/local/cuda-8.0/include/cuda_runtime.h:78:0,
#                  from <command-line>:0:
# /usr/local/cuda-8.0/include/host_config.h:115:2: error: #error -- unsupported GNU version! gcc versions later than 5.3 are not supported!
#  #error -- unsupported GNU version! gcc versions later than 5.3 are not supported!
#   ^
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-35-7a7246af2538> in <module>()
#       9
#      10 model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True), metrics=['accuracy'])
# ---> 11 model.fit(trainx, trainy, batch_size=128, nb_epoch=1, validation_data=(testx,testy))
#      12 evals = model.evaluate(testx, testy, verbose=1)
#      13 print ""
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, **kwargs)
#     427                               shuffle=shuffle,
#     428                               class_weight=class_weight,
# --> 429                               sample_weight=sample_weight)
#     430
#     431     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight)
#    1049                                                                            check_batch_dim=False,
#    1050                                                                            batch_size=batch_size)
# -> 1051             self._make_test_function()
#    1052             val_f = self.test_function
#    1053             if self.uses_learning_phase:
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _make_test_function(self)
#     718                                             [self.total_loss] + self.metrics,
#     719                                             updates=self.state_updates,
# --> 720                                             **self._function_kwargs)
#     721
#     722     def _make_predict_function(self):
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/theano_backend.pyc in function(inputs, outputs, updates, **kwargs)
#     570                 msg = "Invalid argument '%s' passed to K.function" % key
#     571                 raise ValueError(msg)
# --> 572     return Function(inputs, outputs, updates=updates, **kwargs)
#     573
#     574
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/theano_backend.pyc in __init__(self, inputs, outputs, updates, **kwargs)
#     556                                         allow_input_downcast=True,
#     557                                         on_unused_input='warn',
# --> 558                                         **kwargs)
#     559
#     560     def __call__(self, inputs):
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     318                    on_unused_input=on_unused_input,
#     319                    profile=profile,
# --> 320                    output_keys=output_keys)
#     321     # We need to add the flag check_aliased inputs if we have any mutable or
#     322     # borrowed used defined inputs
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1775                    on_unused_input=on_unused_input,
#    1776                    output_keys=output_keys).create(
# -> 1777             defaults)
#    1778
#    1779     t2 = time.time()
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme, storage_map)
#    1639             theano.config.traceback.limit = 0
#    1640             _fn, _i, _o = self.linker.make_thunk(
# -> 1641                 input_storage=input_storage_lists, storage_map=storage_map)
#    1642         finally:
#    1643             theano.config.traceback.limit = limit_orig
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/link.pyc in make_thunk(self, input_storage, output_storage, storage_map)
#     688         return self.make_all(input_storage=input_storage,
#     689                              output_storage=output_storage,
# --> 690                              storage_map=storage_map)[:3]
#     691
#     692     def make_all(self, input_storage, output_storage):
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1001                                                  storage_map,
#    1002                                                  compute_map,
# -> 1003                                                  no_recycling))
#    1004                 if not hasattr(thunks[-1], 'lazy'):
#    1005                     # We don't want all ops maker to think about lazy Ops.
#
# /usr/local/lib/python2.7/dist-packages/theano/sandbox/cuda/__init__.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     254                 enable_cuda=False)
#     255         return super(GpuOp, self).make_thunk(node, storage_map,
# --> 256                                              compute_map, no_recycling)
#     257
#     258 theano.compile.debugmode.default_make_thunk.append(
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     968             try:
#     969                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 970                                          no_recycling)
#     971             except (NotImplementedError, utils.MethodNotDefined):
#     972                 logger.debug('Falling back on perform')
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/op.pyc in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     877         logger.debug('Trying CLinker.make_thunk')
#     878         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 879                                 output_storage=node_output_storage)
#     880         fill_storage, node_input_filters, node_output_filters = outputs
#     881
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1198         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1199             input_storage, output_storage, storage_map,
# -> 1200             keep_lock=keep_lock)
#    1201
#    1202         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1141                                     output_storage,
#    1142                                     storage_map,
# -> 1143                                     keep_lock=keep_lock)
#    1144         return (thunk,
#    1145                 [link.Container(input, storage) for input, storage in
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1593         else:
#    1594             module = get_module_cache().module_from_key(
# -> 1595                 key=key, lnk=self, keep_lock=keep_lock)
#    1596
#    1597         vars = self.inputs + self.outputs + self.orphans
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/cmodule.pyc in module_from_key(self, key, lnk, keep_lock)
#    1140             try:
#    1141                 location = dlimport_workdir(self.dirname)
# -> 1142                 module = lnk.compile_cmodule(location)
#    1143                 name = module.__file__
#    1144                 assert name.startswith(location)
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/cc.pyc in compile_cmodule(self, location)
#    1504                 lib_dirs=self.lib_dirs(),
#    1505                 libs=libs,
# -> 1506                 preargs=preargs)
#    1507         except Exception as e:
#    1508             e.args += (str(self.fgraph),)
#
# /usr/local/lib/python2.7/dist-packages/theano/sandbox/cuda/nvcc_compiler.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, rpaths, py_module, hide_symbols)
#     397             print(cmd)
#     398             raise Exception('nvcc return status', p.returncode,
# --> 399                             'for cmd', ' '.join(cmd))
#     400         elif config.cmodule.compilation_warning and nvcc_stdout:
#     401             print(nvcc_stdout)
#
# Exception: ('The following error happened while compiling the node', GpuElemwise{Add}[(0, 0)](GpuDot22.0, GpuDimShuffle{x,0}.0), '\n', 'nvcc return status', 1, 'for cmd', '/usr/local/cuda-8.0/bin/nvcc -shared -O3 --maxrregcount=32 -arch=sm_52 -m64 -Xcompiler -fno-math-errno,-Wno-unused-label,-Wno-unused-variable,-Wno-write-strings,-DCUDA_NDARRAY_CUH=c72d035fdf91890f3b36710688069b2e,-DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION,-fPIC,-fvisibility=hidden -Xlinker -rpath,/home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/cuda_ndarray -I/home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/cuda_ndarray -I/usr/local/cuda-8.0/include -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -I/usr/include/python2.7 -I/usr/local/lib/python2.7/dist-packages/theano/gof -I/usr/local/lib/python2.7/dist-packages/theano/sandbox/cuda -o /home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/tmpukQQjr/19eaed16bbe8051baf484ccf1bd89231.so mod.cu -L/home/dfh94037/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/cuda_ndarray -L/usr/lib -lcudart -lcublas -lcuda_ndarray -lpython2.7', '[GpuElemwise{Add}[(0, 0)](<CudaNdarrayType(float32, matrix)>, <CudaNdarrayType(float32, row)>)]')

# %%
print results
results.to_csv('results.csv',index=False)
# Out:
#        ImageId  Label
# 0            1      2
# 1            2      0
# 2            3      5
# 3            4      9
# 4            5      2
# 5            6      7
# 6            7      0
# 7            8      3
# 8            9      0
# 9           10      3
# 10          11      5
# 11          12      7
# 12          13      4
# 13          14      0
# 14          15      4
# 15          16      3
# 16          17      3
# 17          18      1
# 18          19      9
# 19          20      0
# 20          21      7
# 21          22      1
# 22          23      1
# 23          24      5
# 24          25      7
# 25          26      9
# 26          27      2
# 27          28      7
# 28          29      7
# 29          30      7
# ...        ...    ...
# 27970    27971      5
# 27971    27972      0
# 27972    27973      4
# 27973    27974      5
# 27974    27975      0
# 27975    27976      3
# 27976    27977      6
# 27977    27978      0
# 27978    27979      1
# 27979    27980      9
# 27980    27981      3
# 27981    27982      1
# 27982    27983      1
# 27983    27984      0
# 27984    27985      4
# 27985    27986      3
# 27986    27987      6
# 27987    27988      2
# 27988    27989      8
# 27989    27990      0
# 27990    27991      7
# 27991    27992      6
# 27992    27993      1
# 27993    27994      4
# 27994    27995      7
# 27995    27996      9
# 27996    27997      7
# 27997    27998      3
# 27998    27999      9
# 27999    28000      2
#
# [28000 rows x 2 columns]
